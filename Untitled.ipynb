# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the data into a variable
data = pd.read_excel('BPD_Part_1_Victim_Based_Crime_Data.xlsx')

# %%
data
# Out:
#         CrimeDate CrimeTime CrimeCode               Location  \
# 0      2020-02-08  02:18:00        5D     1700 CLIFTVIEW AVE
# 1      2020-02-08  06:00:00        6G      700 N STREEPER ST
# 2      2020-02-08  09:50:00       3JF        1400 N BROADWAY
# 3      2020-02-08  09:50:00       3JF        1400 N BROADWAY
# 4      2020-02-08  17:30:00        5A       1600 E OLIVER ST
# ...           ...       ...       ...                    ...
# 292756 1978-01-01  10:30:00        2A        1900 ARGONNE DR
# 292757 1977-05-01  00:01:00        2A          600 W 34TH ST
# 292758 1975-06-01  00:00:00        2A  4400 OLD FREDERICK RD
# 292759 1969-07-20  21:00:00        2A        5400 ROLAND AVE
# 292760 1963-10-30  00:00:00        2A      3100 FERNDALE AVE
#
#                 Description Inside/Outside   Weapon Post   District  \
# 0                  BURGLARY              I      NaN  312    EASTERN
# 1                   LARCENY              I      NaN  333    EASTERN
# ...

# %%
# Look at few deatils of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292761 entries, 0 to 292760
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CrimeDate        292761 non-null  datetime64[ns]
#  1   CrimeTime        292735 non-null  object
#  2   CrimeCode        292761 non-null  object
#  3   Location         291425 non-null  object
#  4   Description      292761 non-null  object
#  5   Inside/Outside   259001 non-null  object
#  6   Weapon           61532 non-null   object
#  7   Post             290385 non-null  object
#  8   District         292761 non-null  object
#  9   Neighborhood     282257 non-null  object
#  10  Longitude        291126 non-null  float64
#  11  Latitude         291126 non-null  float64
#  12  Location 1       0 non-null       float64
#  13  Premise          258749 non-null  object
#  14  vri_name1        34584 non-null   object
#  15  Total Incidents  292761 non-null  int64
# ...

# %%
# Print all the columns
i=1
for col in data.columns:
    print(i,col)
    i+=1
# Out:
# 1 CrimeDate
# 2 CrimeTime
# 3 CrimeCode
# 4 Location
# 5 Description
# 6 Inside/Outside
# 7 Weapon
# 8 Post
# 9 District
# 10 Neighborhood
# 11 Longitude
# 12 Latitude
# 13 Location 1
# 14 Premise
# 15 vri_name1
# 16 Total Incidents

# %%
# Percentage of NIL values
for k in data.keys():
    print('\nPercentage of NIL values for',k,'is:',100*(data[k].isnull().sum())/len(data[k]),'%')
# Out:
# Percentage of NIL values for CrimeDate is: 0.0 %
#
# Percentage of NIL values for CrimeTime is: 0.00888096433609668 %
#
# Percentage of NIL values for CrimeCode is: 0.0 %
#
# Percentage of NIL values for Location is: 0.456344936654814 %
#
# Percentage of NIL values for Description is: 0.0 %
#
# Percentage of NIL values for Inside/Outside is: 11.53159061487015 %
#
# Percentage of NIL values for Weapon is: 78.98217317197305 %
#
# Percentage of NIL values for Post is: 0.8115835100986811 %
#
# Percentage of NIL values for District is: 0.0 %
#
# Percentage of NIL values for Neighborhood is: 3.5879095917830583 %
#
# Percentage of NIL values for Longitude is: 0.5584760265199258 %
#
# Percentage of NIL values for Latitude is: 0.5584760265199258 %
#
# Percentage of NIL values for Location 1 is: 100.0 %
#
# Percentage of NIL values for Premise is: 11.61766765382001 %
#
# Percentage of NIL values for vri_name1 is: 88.18695113078586 %
#
# Percentage of NIL values for Total Incidents is: 0.0 %

# %%
# Print the number of unique values
for k in data.keys():
    print(k, len(data[k].unique()), len(data[k]))
# Out:
# CrimeDate 2300 292761
# CrimeTime 1476 292761
# CrimeCode 81 292761
# Location 27065 292761
# Description 14 292761
# Inside/Outside 5 292761
# Weapon 6 292761
# Post 134 292761
# District 10 292761
# Neighborhood 279 292761
# Longitude 97864 292761
# Latitude 96410 292761
# Location 1 1 292761
# Premise 126 292761
# vri_name1 9 292761
# Total Incidents 1 292761

# %%
# Type of all columns
for k in data.keys():
    print(type(data[k][50]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'datetime.time'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>

# %%
import datetime

data['CrimeDate'].max()
# Out:
# Timestamp('2020-02-08 00:00:00')

# %% [markdown]
# ## 2.	Generate a series of plots to describe the temporal pattern (year-to-year, monthly, and day-of-week) of the overall crime incidence aggregating from all geo-locations

# %%
# Getting values for plots
dict_year={}
dict_month={}
dict_day={}
years=[]
months=[]
days=[]
format = '%Y-%m-%d %H:%M:%S'
for val in data['CrimeDate']:
    year = datetime.datetime.strptime(str(val), format).year
    month = datetime.datetime.strptime(str(val), format).month
    day = datetime.datetime.strptime(str(val), format).weekday()
    years.append(year)
    months.append(month)
    days.append(day)
    if year in dict_year:
        dict_year[year] +=1
    else:
        dict_year[year] =1
    if month in dict_month:
        dict_month[month]+=1
    else:
        dict_month[month] = 1
    if day in dict_day:
        dict_day[day]+=1
    else:
        dict_day[day] = 1

# %%
data['year'] = years
data['month'] = months
data['day'] = days

# %%
# Check values year wise
dict_year
# Out:
# {2020: 3809,
#  2019: 45998,
#  2018: 48436,
#  2017: 52163,
#  2016: 48774,
#  2015: 48192,
#  2014: 45307,
#  2013: 15,
#  2012: 10,
#  2011: 9,
#  2010: 3,
#  2009: 7,
#  2008: 5,
#  2007: 5,
#  2006: 1,
#  2004: 2,
#  2003: 1,
#  2001: 3,
#  2000: 3,
#  1999: 2,
#  1998: 2,
#  1995: 2,
#  1993: 2,
#  1988: 1,
#  1985: 1,
#  1982: 1,
#  1981: 1,
#  1980: 1,
#  1978: 1,
#  1977: 1,
#  1975: 1,
#  1969: 1,
#  1963: 1}

# %%
# Check values month wise
dict_month
# Out:
# {2: 19023,
#  1: 25680,
#  12: 23626,
#  11: 23921,
#  10: 26398,
#  9: 25641,
#  8: 26571,
#  7: 26358,
#  6: 25750,
#  5: 25692,
#  4: 23065,
#  3: 21036}

# %%
# Check values day of the week wise
dict_day
# Out:
# {5: 40638, 4: 43661, 3: 41746, 2: 42036, 1: 42325, 0: 43017, 6: 39338}

# %% [markdown]
# #### Day of week wise in increasing order

# %%
data['day'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Year wise in increasing order

# %%
data['year'].value_counts()[:10].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Month wise in increasing order

# %%
data['month'].value_counts()[:10].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
myList = dict_year.items()
myList = sorted(myList)[-8:] 
x, y = zip(*myList) 

plt.bar(x, y)
plt.title('Year wise crime rates')
plt.show()

# %%
myList = dict_month.items()
myList = sorted(myList) 
x, y = zip(*myList) 

plt.bar(x, y)
plt.title('Month wise crime rates')
plt.show()

# %%
myList = dict_day.items()
myList = sorted(myList)[-8:] 
x, y = zip(*myList) 

plt.bar(x, y)
plt.title('Day of the week wise crime rates')
plt.show()

# %% [markdown]
# ## 3.	Generate a plot describing the distribution of crime type aggregating from all geo-locations and all time periods

# %%
dict_crime={}
for val in data['Description']:
    if val in dict_crime:
        dict_crime[val]+=1
    else:
        dict_crime[val] = 1

# %%
dict_crime
# Out:
# {'BURGLARY': 42237,
#  'LARCENY': 65508,
#  'ROBBERY - RESIDENCE': 2984,
#  'AUTO THEFT': 25832,
#  'ROBBERY - COMMERCIAL': 5190,
#  'ROBBERY - STREET': 20779,
#  'COMMON ASSAULT': 48061,
#  'SHOOTING': 3869,
#  'AGG. ASSAULT': 31706,
#  'LARCENY FROM AUTO': 38977,
#  'ROBBERY - CARJACKING': 2554,
#  'HOMICIDE': 1902,
#  'RAPE': 1891,
#  'ARSON': 1271}

# %%
myList = dict_crime.items()
myList = list(sorted(myList))
myList1 = list(sorted(myList)[:8])
myList2 = list(sorted(myList)[1:])
#myList2 += myList1[1] + myList1[4]

del myList1[1]
del myList1[4]
myList1.append(myList[-2])

del myList2[1]
del myList2[1]
del myList2[1]
del myList2[2]
del myList2[2]
del myList2[-2]
# x, y = zip(*myList) 

# plt.rc('xtick',labelsize=7)

# plt.bar(x, y)
# plt.show()

# %%
x, y = zip(*myList1) 

plt.figure(figsize=(20, 10))
plt.bar(x, y)
plt.show()

# %%
x, y = zip(*myList2) 

plt.figure(figsize=(20, 10))
plt.bar(x, y)
plt.show()

# %% [markdown]
# ## 4.	Generate a series of plots to illustrate how crime types distributions might vary from year-to-year, month-to-month, or by day-of-week aggregating across all locations

# %%
x=[]
counts=[]
for i in dict_crime.items():
    y = []
    for year in data['year'].unique():
        count = len(data[(data['year'] == year) & (data['Description'] == i[0]) ])
        y.append(count)
    counts.append(y)
    x.append(i[0])

# %%
y=[]
for year in data['year'].unique():
    y.append(year)

# %%
x
# Out:
# ['BURGLARY',
#  'LARCENY',
#  'ROBBERY - RESIDENCE',
#  'AUTO THEFT',
#  'ROBBERY - COMMERCIAL',
#  'ROBBERY - STREET',
#  'COMMON ASSAULT',
#  'SHOOTING',
#  'AGG. ASSAULT',
#  'LARCENY FROM AUTO',
#  'ROBBERY - CARJACKING',
#  'HOMICIDE',
#  'RAPE',
#  'ARSON']

# %%
c = np.array(counts)

# %%
c[:,0]
# Out:
# array([419, 870,  60, 342,  68, 262, 752,  52, 423, 449,  67,  32,  12,
#          1])

# %%
plt.figure(figsize=(15, 8))

plt.plot(y[:10],counts[8][:10])
plt.plot(y[:10],counts[3][:10])
plt.plot(y[:10],counts[0][:10])
plt.plot(y[:10],counts[6][:10])
plt.plot(y[:10],counts[1][:10])
plt.plot(y[:10],counts[9][:10])
plt.plot(y[:10],counts[5][:10])

plt.legend([x[8],x[3],x[0],x[6],x[1],x[9],x[5]])

# %%
plt.figure(figsize=(15, 8))

plt.plot(y[:10],counts[2][:10])
plt.plot(y[:10],counts[4][:10])
plt.plot(y[:10],counts[7][:10])
plt.plot(y[:10],counts[10][:10])
plt.plot(y[:10],counts[11][:10])
plt.plot(y[:10],counts[12][:10])
plt.plot(y[:10],counts[13][:10])

plt.legend([x[2],x[4],x[7],x[10],x[11],x[12],x[13]])

# %%
x=[]
counts=[]
for i in dict_crime.items():
    y = []
    for month in sorted(data['month'].unique()):
        count = len(data[(data['month'] == month) & (data['Description'] == i[0]) ])
        y.append(count)
    counts.append(y)
    x.append(i[0])

# %%
m=[]
for month in sorted(data['month'].unique()):
    m.append(month)

# %%
plt.figure(figsize=(15, 8))


plt.plot(m,counts[8])
plt.plot(m,counts[3])
plt.plot(m,counts[0])
plt.plot(m,counts[6])
plt.plot(m,counts[1])
plt.plot(m,counts[9])
plt.plot(m,counts[5])

plt.legend([x[8],x[3],x[0],x[6],x[1],x[9],x[5]])

# %%
plt.figure(figsize=(15, 8))


plt.plot(m,counts[2])
plt.plot(m,counts[4])
plt.plot(m,counts[7])
plt.plot(m,counts[10])
plt.plot(m,counts[11])
plt.plot(m,counts[12])
plt.plot(m,counts[13])

plt.legend([x[2],x[4],x[7],x[10],x[11],x[12],x[13]])

# %%
x=[]
counts=[]
for i in dict_crime.items():
    y = []
    for day in sorted(data['day'].unique()):
        count = len(data[(data['day'] == day) & (data['Description'] == i[0]) ])
        y.append(count)
    counts.append(y)
    x.append(i[0])

# %%
d=[]
for day in sorted(data['day'].unique()):
    d.append(day)
print(d)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
plt.figure(figsize=(15, 8))


plt.plot(d,counts[8])
plt.plot(d,counts[3])
plt.plot(d,counts[0])
plt.plot(d,counts[6])
plt.plot(d,counts[1])
plt.plot(d,counts[9])
plt.plot(d,counts[5])

plt.legend([x[8],x[3],x[0],x[6],x[1],x[9],x[5]])

# %%
plt.figure(figsize=(15, 8))


plt.plot(d,counts[2])
plt.plot(d,counts[4])
plt.plot(d,counts[7])
plt.plot(d,counts[10])
plt.plot(d,counts[11])
plt.plot(d,counts[12])
plt.plot(d,counts[13])

plt.legend([x[2],x[4],x[7],x[10],x[11],x[12],x[13]])

# %% [markdown]
# ## 5. Trying analysis with other columns

# %%
dict_weapons={}
for val in data['Weapon']:
    if val in dict_weapons:
        dict_weapons[val] +=1
    else:
        dict_weapons[val] =1

# %%
data['Weapon'].value_counts().plot(kind='barh')
dict_weapons
# Out:
# {nan: 231229,
#  'FIREARM': 29036,
#  'OTHER': 17313,
#  'KNIFE': 10023,
#  'HANDS': 3889,
#  'FIRE': 1271}

# %% [markdown]
# ### As the whole thing is commented and documented properly, you can change the required values in any part of code and get the required result
